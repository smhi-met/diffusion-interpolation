# %%
import torch

# %%
check_pont_path = '/perm/smcd/github/diffusion-interpolation/_work/simple-conv-ae/test_20260302_022919/checkpoints/last.ckpt'

# %%
ckpt = torch.load(check_pont_path, map_location="cpu")

# %%
print(ckpt.keys())

# %%
print(ckpt['state_dict'].keys())

# %%
ckpt['state_dict']['normalizer.minimum']

# %%
ckpt['state_dict']['normalizer.maximum']

# %%
ckpt['epoch']

# %%
check_pont_path = '/perm/smcd/github/diffusion-interpolation/_work/simple-conv-ae/test_20260302_022919/checkpoints/last.ckpt'

# %%
r_ckpt = torch.load(check_pont_path, map_location="cpu")
