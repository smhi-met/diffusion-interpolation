# %%
import os
import numpy as np
import xarray as xr
import zarr

import dask
import matplotlib.pyplot as plt

from dask.diagnostics import ProgressBar

# %%
file_path='/project/home/p200177/u101329/DE371_bis/MEPS_subdomain/meps-2p5km-2020-2025-1h-v2_subdomain_subvars.zarr'

# %%
ds = xr.open_zarr(file_path, zarr_format=2)

# %%
print(ds)

# %%
print(ds.attrs['variables'])

# %%
print(len(ds.attrs['variables']))

# %%
file_path='/mnt/tier1/project/p200177/DE_371_bis/meps-2p5km-2020-2025-1h-v2_subdomain_subvars_rechu.zarr'

# %%
ds = xr.open_zarr(file_path, zarr_format=2)

# %%
print(ds)

# %%
print(ds.attrs['variables'])

# %%
print(len(ds.attrs['variables']))
